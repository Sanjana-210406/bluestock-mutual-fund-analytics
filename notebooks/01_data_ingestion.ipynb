# %%
import pandas as pd

fund_master = pd.read_csv(
    "../data/raw/01_fund_master.csv"
)
fund_master.head()

# %%
nav_history = pd.read_csv("../data/raw/02_nav_history.csv")
master_codes = set(fund_master["amfi_code"])
nav_codes = set(nav_history["amfi_code"])
missing_codes = master_codes - nav_codes

print("Missing Codes:")
print(missing_codes)

print("\nNumber of Missing Codes:")
print(len(missing_codes))

# %%
print("Unique Fund Houses:\n")
print(fund_master["fund_house"].unique())

# %%
print("Categories:\n")
print(fund_master["category"].unique())

# %%
print("Sub Categories:\n")
print(fund_master["sub_category"].unique())

# %%
print("Risk Categories:\n")
print(fund_master["risk_category"].unique())

# %%
print("Total Schemes:")
print(fund_master["amfi_code"].nunique())

print("\nSample AMFI Codes:")
print(fund_master["amfi_code"].head(10))

# %% [markdown]
# Fund Master Insights
#
# - Total schemes: 40
# - Multiple fund houses represented
# - Categories include Equity, Debt and Hybrid
# - Various sub-categories such as Large Cap, Small Cap, Mid Cap, Liquid etc.
# - Risk categories range from Low to Very High
# - Each scheme is uniquely identified using an AMFI code
